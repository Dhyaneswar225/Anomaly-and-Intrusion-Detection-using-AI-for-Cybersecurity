# %%
import pandas as pd
df = pd.read_csv('F:\\Master Thesis\\anomaly-ids\\data\\processed\\train_processed.csv')
unique_values = df['label_attack'].unique()
sortedunique=sorted(unique_values)
df2 = pd.read_csv('F:\\Master Thesis\\anomaly-ids\\data\\processed\\KDDTest+.csv')
unique_values2 = df2['label'].unique()
sortedunique2=sorted(unique_values2)
intersect=set(sortedunique).intersection(set(sortedunique2))
print("Attacks in Train:",sortedunique)
print("Count of Attacks in Train:",len(unique_values)-1)
print("Attacks in Test:",sortedunique2)
print("Count of Attacks in Test:",len(unique_values2)-1)
print("Common attacks in both Train and Test:",intersect)
uniqueattacks1=set(sortedunique).union(set(sortedunique2)) - intersect
print("Unique attacks in Train and Test:",uniqueattacks1)
print("Count of unique attacks in Train and Test:",len(uniqueattacks1))
print("Count of common attacks in both:",len(intersect))
print("Total attacks in Train and Test:",len(unique_values)+len(unique_values2)-len(intersect)-1)
# Out:
# Attacks in Train: ['back', 'buffer_overflow', 'ftp_write', 'guess_passwd', 'imap', 'ipsweep', 'land', 'loadmodule', 'multihop', 'neptune', 'nmap', 'normal', 'perl', 'phf', 'pod', 'portsweep', 'rootkit', 'satan', 'smurf', 'spy', 'teardrop', 'warezclient', 'warezmaster']
# Count of Attacks in Train: 22
# Attacks in Test: ['apache2', 'back', 'buffer_overflow', 'ftp_write', 'guess_passwd', 'httptunnel', 'imap', 'ipsweep', 'land', 'loadmodule', 'mailbomb', 'mscan', 'multihop', 'named', 'neptune', 'nmap', 'normal', 'perl', 'phf', 'pod', 'portsweep', 'processtable', 'ps', 'rootkit', 'saint', 'satan', 'sendmail', 'smurf', 'snmpgetattack', 'snmpguess', 'sqlattack', 'teardrop', 'udpstorm', 'warezmaster', 'worm', 'xlock', 'xsnoop', 'xterm']
# Count of Attacks in Test: 37
# ...
